# %%
import pymysql
import pandas as pd
import numpy as np
import konlpy

# %%
#데이터 가져오기
db = pymysql.connect(host='220.86.191.27', port=3306, user='playdata', password='playdata123!', db='bookdata', charset='utf8')

curs = db.cursor(pymysql.cursors.DictCursor)

query = '''
select *
    from books_data'''
df_books_data = pd.read_sql(query, db)

# %%
df_books_data.head()
# Out:
#    id                title    author           pub     date  price  review  \
# 0   1              요리코를 위해  노리즈키 린타로            모모  2020.03  13500      43
# 1   2         그녀는 다 계획이 있다  히가시노 게이고          하빌리스  2021.02  14220      13
# 2   3  블랙 쇼맨과 이름 없는 마을의 살인  히가시노 게이고  알에이치코리아(RHK)  2020.11  16200      54
# 3   4          돌이킬 수 없는 약속   야쿠마루 가쿠          북플라자  2017.02  13500     217
# 4   5                루팡의 딸   요코제키 다이          북플라자  2019.09  13500      31
#
#    rating                                              story  \
# 0     9.2  스스로 악마 이자 신 딸 살해 남자 심판 아버지 비극 출발 이자 마지막 끝내 실체 ...
# 1     9.4  하나 보석 점 살인 사건 과거 미래 사건 경쾌하다 리듬 감 있다 터치 게이고 복고 ...
# 2     9.1  아버지 살해 당하다 그것 결혼 소식 직후 행복하다 순간 비극 시작 대기업 취직 후 ...
# 3     8.2  제 에드가 란 포상 수상 작가 야쿠 마루 가쿠 미스터리 추리 소설 내 딸 살해 놈 ...
# 4     8.5  도둑 집안 대부 변 사체 발견 도둑 집안 대부 이 오 하나 코 손녀 딸 있다 하나 ...
#
#                                        img    genre
# 0  http://image.yes24.com/goods/89392792/L  추리/미스터리
# 1  http://image.yes24.com/goods/97561319/L  추리/미스터리
# 2  http://image.yes24.com/goods/95712763/L  추리/미스터리
# 3  http://image.yes24.com/goods/35552641/L  추리/미스터리
# 4  http://image.yes24.com/goods/78860364/L  추리/미스터리

# %%
#스토리의 키워드를 뽑기위해 명사와 형용사만 가져오자
story_words = df_books_data['story'].to_numpy()
for i, document in enumerate(story_words):
    okt = konlpy.tag.Okt()
    clean_words = []
    for word in okt.pos(document, stem = True): #어간 뽑자
        if word[1] in ['Noun', 'Adjective']: #명사, 형용사만 가져와
            clean_words.append(word[0])
    #print(clean_words)
    document = ' '.join(clean_words)
    #print(document)
    story_words[i] = document

# %%
#넘파이 배열 데이터프레임 화
df_story_words=pd.DataFrame(story_words,
            columns = ['story_words'])

# %%
df_books = pd.concat([df_books_data, df_story_words], axis = 1)

# %%
df_books.columns
# Out:
# Index(['title', 'author', 'pub', 'price', 'review', 'rating', 'story', 'img',
#        'genre', 'story_words'],
#       dtype='object')

# %%
#날짜, 아이디 날리고
df_books = df_books.drop(['id','date'],axis = 1)

# %%
#혹시모를 중복 제거하자
df_books = df_books.drop_duplicates(['title'])

# %%
df_books.tail()
# Out:
#                     title author           pub  price  review  rating  \
# 79768              그녀를 위해                신영미디어   2880       0     0.0
# 79769           하루만 사랑해 1         파피루스(디앤씨미디어)   8100       1     7.0
# 79770           하루만 사랑해 2         파피루스(디앤씨미디어)   8100       0     0.0
# 79771  서울 여자와 대구 남자가 만날 때     정민          영상노트   8100       0     0.0
# 79772          kiss me...                   현무   7200       2     5.0
#
#                                                    story  \
# 79768  마르코 고아 조카 안젤리나 사람 필요하다 양육 위 편의 상의 아내 성실하다 착하다 ...
# 79769  날 서원 횡단보도 교통사고 당하다 상대 인천 상고 짱 노랗다 머 민 하루 놈 오히려...
# 79770  날 서원 횡단보도 교통사고 당하다 상대 인천 상고 짱 노랗다 머 민 하루 놈 오히려...
# 79771
# 79772
#
#                                          img genre  \
# 79768  http://image.yes24.com/goods/373089/L   로맨스
# 79769  http://image.yes24.com/goods/375482/L   로맨스
# 79770  http://image.yes24.com/goods/375484/L   로맨스
# 79771  http://image.yes24.com/goods/376458/L   로맨스
# 79772  http://image.yes24.com/goods/377351/L   로맨스
#
#                                              story_words
# 79768  마르코 고아 조카 안젤리나 사람 필요하다 양육 위 편의 상의 아내 성실하다 착하다 ...
# 79769  날 서원 횡단보도 교통사고 당하다 상대 인천 상고 짱 노랗다 머 민 하루 놈 오히려...
# 79770  날 서원 횡단보도 교통사고 당하다 상대 인천 상고 짱 노랗다 머 민 하루 놈 오히려...
# 79771
# 79772

# %%
#세트책들 날리자
df_books_tu=df_books[df_books['title'].str.contains('세트')==False]

# %%
df_books2 = df_books_tu.reset_index()

# %%
df_books2.tail()
# Out:
#        index               title author           pub  price  review  rating  \
# 73503  79768              그녀를 위해                신영미디어   2880       0     0.0
# 73504  79769           하루만 사랑해 1         파피루스(디앤씨미디어)   8100       1     7.0
# 73505  79770           하루만 사랑해 2         파피루스(디앤씨미디어)   8100       0     0.0
# 73506  79771  서울 여자와 대구 남자가 만날 때     정민          영상노트   8100       0     0.0
# 73507  79772          kiss me...                   현무   7200       2     5.0
#
#                                                    story  \
# 73503  마르코 고아 조카 안젤리나 사람 필요하다 양육 위 편의 상의 아내 성실하다 착하다 ...
# 73504  날 서원 횡단보도 교통사고 당하다 상대 인천 상고 짱 노랗다 머 민 하루 놈 오히려...
# 73505  날 서원 횡단보도 교통사고 당하다 상대 인천 상고 짱 노랗다 머 민 하루 놈 오히려...
# 73506
# 73507
#
#                                          img genre  \
# 73503  http://image.yes24.com/goods/373089/L   로맨스
# 73504  http://image.yes24.com/goods/375482/L   로맨스
# 73505  http://image.yes24.com/goods/375484/L   로맨스
# 73506  http://image.yes24.com/goods/376458/L   로맨스
# 73507  http://image.yes24.com/goods/377351/L   로맨스
#
#                                              story_words
# 73503  마르코 고아 조카 안젤리나 사람 필요하다 양육 위 편의 상의 아내 성실하다 착하다 ...
# 73504  날 서원 횡단보도 교통사고 당하다 상대 인천 상고 짱 노랗다 머 민 하루 놈 오히려...
# 73505  날 서원 횡단보도 교통사고 당하다 상대 인천 상고 짱 노랗다 머 민 하루 놈 오히려...
# 73506
# 73507

# %%
#인덱스 칼럼 날려줍시다
df_book = df_books2.drop(['index'], axis =1)

# %%
#아 스토리랑 스토리 워드랑 똑같아 졌다.. 둘다 갖고있지 말고 하나 날리자
df_book = df_book.drop(['story_words'],axis = 1)

# %%
df_book.head()
# Out:
#                  title    author           pub  price  review  rating  \
# 0              요리코를 위해  노리즈키 린타로            모모  13500      43     9.2
# 1         그녀는 다 계획이 있다  히가시노 게이고          하빌리스  14220      13     9.4
# 2  블랙 쇼맨과 이름 없는 마을의 살인  히가시노 게이고  알에이치코리아(RHK)  16200      54     9.1
# 3          돌이킬 수 없는 약속   야쿠마루 가쿠          북플라자  13500     217     8.2
# 4                루팡의 딸   요코제키 다이          북플라자  13500      31     8.5
#
#                                                story  \
# 0  스스로 악마 이자 신 딸 살해 남자 심판 아버지 비극 출발 이자 마지막 끝내 실체 ...
# 1  하나 보석 점 살인 사건 과거 미래 사건 경쾌하다 리듬 감 있다 터치 게이고 복고 ...
# 2  아버지 살해 당하다 그것 결혼 소식 직후 행복하다 순간 비극 시작 대기업 취직 후 ...
# 3  제 에드가 란 포상 수상 작가 야쿠 마루 가쿠 미스터리 추리 소설 내 딸 살해 놈 ...
# 4  도둑 집안 대부 변 사체 발견 도둑 집안 대부 이 오 하나 코 손녀 딸 있다 하나 ...
#
#                                        img    genre
# 0  http://image.yes24.com/goods/89392792/L  추리/미스터리
# 1  http://image.yes24.com/goods/97561319/L  추리/미스터리
# 2  http://image.yes24.com/goods/95712763/L  추리/미스터리
# 3  http://image.yes24.com/goods/35552641/L  추리/미스터리
# 4  http://image.yes24.com/goods/78860364/L  추리/미스터리
