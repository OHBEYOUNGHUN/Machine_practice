# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels
import statsmodels.api as sm
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# ## 데이터셋

# %%
#데이터 읽자
#천단위 콤마 제거 해주자 나중에 또 하기 귀찮으니까!(결정적으로 float형 유지를 위해)
df = pd.read_csv('exchange_rate_fix_20210223.xls.csv', thousands = ',')
print(df.shape)
df.tail()
# Out:
# (1762, 8)
#             Date ExchangeRate   KRX100  KORIBOR  LIBOR  달러지수 (종가)   콜금리  \
# 1757  2021.02.17     1,099.70  6764.11     0.87    NaN      90.95  0.47
# 1758  2021.02.18     1,107.70  6652.76     0.87    NaN      90.59  0.49
# 1759  2021.02.19     1,105.70  6712.32     0.86    NaN      90.36  0.51
# 1760  2021.02.22     1,107.10  6635.92     0.86    NaN      90.01  0.50
# 1761  2021.02.23     1,106.50  6607.24     0.86    NaN      90.17  0.49
#
#          KOSPI
# 1757  3,133.73
# 1758  3,086.66
# 1759  3,107.62
# 1760  3,079.75
# 1761  3,070.09

# %%
#열이름 한국어인거 영어로 변경하자
name = ["Date", "ExchangeRate","KRX100", "KORIBOR", "LIBOR", "DollarRate",
       "CallRate","KOSPI"]
df1= df.rename(columns = dict(zip(df.columns,name)))

# %%
#천단위 쉼표 제거
df1['ExchangeRate'] = df1['ExchangeRate'].str.replace(',','')
df1['KOSPI'] = df1['KOSPI'].str.replace(',','')
df1.tail()
# Out:
#             Date ExchangeRate   KRX100  KORIBOR  LIBOR  DollarRate  CallRate  \
# 1757  2021.02.17      1099.70  6764.11     0.87    NaN       90.95      0.47
# 1758  2021.02.18      1107.70  6652.76     0.87    NaN       90.59      0.49
# 1759  2021.02.19      1105.70  6712.32     0.86    NaN       90.36      0.51
# 1760  2021.02.22      1107.10  6635.92     0.86    NaN       90.01      0.50
# 1761  2021.02.23      1106.50  6607.24     0.86    NaN       90.17      0.49
#
#         KOSPI
# 1757  3133.73
# 1758  3086.66
# 1759  3107.62
# 1760  3079.75
# 1761  3070.09

# %%
#오브젝트형 데이터 실수로 형변환
df1["KOSPI"] = pd.to_numeric(df1.KOSPI, errors='coerce')
df1["ExchangeRate"] = pd.to_numeric(df1.ExchangeRate, errors='coerce')

# %%
#결측값 확인
df1.isna().sum()
# Out:
# Date             0
# ExchangeRate     1
# KRX100           6
# KORIBOR          0
# LIBOR           92
# DollarRate       7
# CallRate         0
# KOSPI            7
# dtype: int64

# %%
#결측치를 값에 선형 비례하는식으로 결측값을 보간해봤다
df_intp = df1.interpolate(method = 'values')

df_intp.tail()
# Out:
#             Date  ExchangeRate   KRX100  KORIBOR   LIBOR  DollarRate  \
# 1757  2021.02.17        1099.7  6764.11     0.87  0.0815       90.95
# 1758  2021.02.18        1107.7  6652.76     0.87  0.0815       90.59
# 1759  2021.02.19        1105.7  6712.32     0.86  0.0815       90.36
# 1760  2021.02.22        1107.1  6635.92     0.86  0.0815       90.01
# 1761  2021.02.23        1106.5  6607.24     0.86  0.0815       90.17
#
#       CallRate    KOSPI
# 1757      0.47  3133.73
# 1758      0.49  3086.66
# 1759      0.51  3107.62
# 1760      0.50  3079.75
# 1761      0.49  3070.09

# %%
#날짜 데이터타임형식으로 미리 변경해놓자
df_intp['Date'] = pd.to_datetime(df_intp['Date'], errors='coerce')

# %%
df_intp.head()
# Out:
#          Date  ExchangeRate   KRX100  KORIBOR   LIBOR  DollarRate  CallRate  \
# 0  2014.01.02        1055.3  4263.64     2.78  0.0956       80.79      2.51
# 1  2014.01.03        1050.4  4209.03     2.78  0.0950       80.96      2.50
# 2  2014.01.06        1054.1  4221.13     2.77  0.0945       80.81      2.48
# 3  2014.01.07        1062.2  4233.05     2.75  0.0926       80.98      2.50
# 4  2014.01.08        1067.9  4232.26     2.75  0.0925       81.16      2.49
#
#      KOSPI
# 0  1967.19
# 1  1946.14
# 2  1953.28
# 3  1959.44
# 4  1958.96

# %%
#날짜가 인덱스인 경우도 생성 해놓자
df_date = df_intp.set_index('Date')
df_date.head()
# Out:
#             ExchangeRate   KRX100  KORIBOR   LIBOR  DollarRate  CallRate  \
# Date
# 2014.01.02        1055.3  4263.64     2.78  0.0956       80.79      2.51
# 2014.01.03        1050.4  4209.03     2.78  0.0950       80.96      2.50
# 2014.01.06        1054.1  4221.13     2.77  0.0945       80.81      2.48
# 2014.01.07        1062.2  4233.05     2.75  0.0926       80.98      2.50
# 2014.01.08        1067.9  4232.26     2.75  0.0925       81.16      2.49
#
#               KOSPI
# Date
# 2014.01.02  1967.19
# 2014.01.03  1946.14
# 2014.01.06  1953.28
# 2014.01.07  1959.44
# 2014.01.08  1958.96

# %%
#시각화 해보자
df_intp.plot(x="Date",figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#개별 시각화
groups = [0,1,2,3,4,5,6]
i = 1
#그래프
plt.figure()
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(df_date.values[:,group])
    plt.title(df_date.columns[group], y= 0.5, loc= 'right')
    i +=1
    plt.show()

# %% [markdown]
# ##  차분
# - 데이터가 정상성을 유지 해야하되니까 꼭 해주자
# - 그 전에 정상성을 갖고있는지 부터 확인 (adf 검정)

# %% [markdown]
# - 귀무가설 : 시계열 변수가 정상성을 갖고 있지 않다(단위근을 갖는다)
# - 대립가설 : 시계열 변수가 정상성을 갖고있다

# %%
#환율
adfuller_test = adfuller(df_date['ExchangeRate'], autolag = "AIC")
print ("ExchangeRate ADF test statistic : {}".format(adfuller_test[0]))
print("p-value: {}".format(adfuller_test[1]))
#krx100
adfuller_test = adfuller(df_date['KRX100'], autolag = "AIC")
print ("KRX100 ADF test statistic : {}".format(adfuller_test[0]))
print("p-value: {}".format(adfuller_test[1]))
#koribor
adfuller_test = adfuller(df_date['KORIBOR'], autolag = "AIC")
print ("KORIBOR ADF test statistic : {}".format(adfuller_test[0]))
print("p-value: {}".format(adfuller_test[1]))
#libor
adfuller_test = adfuller(df_date['LIBOR'], autolag = "AIC")
print ("LIBOR ADF test statistic : {}".format(adfuller_test[0]))
print("p-value: {}".format(adfuller_test[1]))
#Dollarrate
adfuller_test = adfuller(df_date['DollarRate'], autolag = "AIC")
print ("DollarRate ADF test statistic : {}".format(adfuller_test[0]))
print("p-value: {}".format(adfuller_test[1]))
#callrate
adfuller_test = adfuller(df_date['CallRate'], autolag = "AIC")
print ("CallRate ADF test statistic : {}".format(adfuller_test[0]))
print("p-value: {}".format(adfuller_test[1]))
#kospi
adfuller_test = adfuller(df_date['KOSPI'], autolag = "AIC")
print ("KOSPI ADF test statistic : {}".format(adfuller_test[0]))
print("p-value: {}".format(adfuller_test[1]))
# Out:
# ExchangeRate ADF test statistic : -2.596813831487721
# p-value: 0.09365757339119885
# KRX100 ADF test statistic : 0.0516464188993991
# p-value: 0.9626004362776712
# KORIBOR ADF test statistic : -1.2280519809925396
# p-value: 0.6614135724495864
# LIBOR ADF test statistic : -1.0777430677367463
# p-value: 0.72386561802668
# DollarRate ADF test statistic : -2.406499234649235
# p-value: 0.13991044403923425
# CallRate ADF test statistic : -1.1195367311553965
# p-value: 0.7072183357711792
# KOSPI ADF test statistic : -0.3267097127774202
# p-value: 0.9216353251449864

# %% [markdown]
# ### 정상성을 하나도 띄지 않는다
# - 차분을 취하자

# %%
df_diff = df_date.diff().dropna()

# %%
#다시 테스트 해서 확인해보자
#환율
adfuller_test = adfuller(df_diff['ExchangeRate'], autolag = "AIC")
print ("ExchangeRate ADF test statistic : {}".format(adfuller_test[0]))
print("p-value: {}".format(adfuller_test[1]))
#krx100
adfuller_test = adfuller(df_diff['KRX100'], autolag = "AIC")
print ("KRX100 ADF test statistic : {}".format(adfuller_test[0]))
print("p-value: {}".format(adfuller_test[1]))
#koribor
adfuller_test = adfuller(df_diff['KORIBOR'], autolag = "AIC")
print ("KORIBOR ADF test statistic : {}".format(adfuller_test[0]))
print("p-value: {}".format(adfuller_test[1]))
#libor
adfuller_test = adfuller(df_diff['LIBOR'], autolag = "AIC")
print ("LIBOR ADF test statistic : {}".format(adfuller_test[0]))
print("p-value: {}".format(adfuller_test[1]))
#Dollarrate
adfuller_test = adfuller(df_diff['DollarRate'], autolag = "AIC")
print ("DollarRate ADF test statistic : {}".format(adfuller_test[0]))
print("p-value: {}".format(adfuller_test[1]))
#callrate
adfuller_test = adfuller(df_diff['CallRate'], autolag = "AIC")
print ("CallRate ADF test statistic : {}".format(adfuller_test[0]))
print("p-value: {}".format(adfuller_test[1]))
#kospi
adfuller_test = adfuller(df_diff['KOSPI'], autolag = "AIC")
print ("KOSPI ADF test statistic : {}".format(adfuller_test[0]))
print("p-value: {}".format(adfuller_test[1]))
# Out:
# ExchangeRate ADF test statistic : -27.61967494215865
# p-value: 0.0
# KRX100 ADF test statistic : -27.130556188141195
# p-value: 0.0
# KORIBOR ADF test statistic : -17.476000137606594
# p-value: 4.515977505592858e-30
# LIBOR ADF test statistic : -10.814087062367125
# p-value: 1.8764247893364856e-19
# DollarRate ADF test statistic : -18.696371604614022
# p-value: 2.0380289312383375e-30
# CallRate ADF test statistic : -27.024997906129105
# p-value: 0.0
# KOSPI ADF test statistic : -26.667306624000034
# p-value: 0.0

# %% [markdown]
# ## 모델링
# - 데이터를 트레인/테스트 셋으로 나누자

# %%
#80퍼 
train = df_diff.iloc[:int(0.8 * len(df_date)), :]   
test = df_diff.iloc[int(0.8 * len(df_date)):, :]

# %%
test.tail()
# Out:
#             ExchangeRate  KRX100  KORIBOR  LIBOR  DollarRate  CallRate  KOSPI
# Date
# 2021.02.17          -3.4  -77.34     0.00    0.0        0.44     -0.03 -29.52
# 2021.02.18           8.0 -111.35     0.00    0.0       -0.36      0.02 -47.07
# 2021.02.19          -2.0   59.56    -0.01    0.0       -0.23      0.02  20.96
# 2021.02.22           1.4  -76.40     0.00    0.0       -0.35     -0.01 -27.87
# 2021.02.23          -0.6  -28.68     0.00    0.0        0.16     -0.01  -9.66

# %% [markdown]
# ### var 모델의 최적순서 찾자
# - var 모델링 과정에서, 최적 AIC를 모델 선택 기준으로 하자
# - 그니까 최상의 aic 점수를 바탕으로 var의 p를 선택하자
# - p가 커지면 aic 점수가 감소하고 이후 점수가 높아지기 사직하는 것을 의미

# %%
forecasting_model = VAR(train)
results_aic = []
for p in range(1,10):
    results = forecasting_model.fit(p)
    results_aic.append(results.aic)
# Out:
# C:\Users\82102\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:583: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
sns.set()
plt.plot(list(np.arange(1,10,1)), results_aic)
plt.ylabel("AIC")
plt.show()

# %% [markdown]
# - 그래프 가장 낮은점수가 2이니까 그 이후는 증가추세를 보이기 때문에 최적 순서는 2

# %%
results = forecasting_model.fit(2)
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 07, Mar, 2021
# Time:                     17:00:21
# --------------------------------------------------------------------
# No. of Equations:         7.00000    BIC:                   -13.1659
# Nobs:                     1407.00    HQIC:                  -13.4112
# Log likelihood:          -4332.33    FPE:                1.29419e-06
# AIC:                     -13.5576    Det(Omega_mle):     1.20160e-06
# --------------------------------------------------------------------
# Results for equation ExchangeRate
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.037653         0.118601            0.317           0.751
# L1.ExchangeRate         0.010267         0.024772            0.414           0.679
# L1.KRX100               0.035126         0.015054            2.333           0.020
# L1.KORIBOR            -16.715227        12.701437           -1.316           0.188
# L1.LIBOR               -8.294710         5.508529           -1.506           0.132
# L1.DollarRate           1.231083         0.285667            4.310           0.000
# L1.CallRate             1.000826         4.916005            0.204           0.839
# L1.KOSPI               -0.196337         0.032454           -6.050           0.000
# L2.ExchangeRate        -0.028539         0.022688           -1.258           0.208
# L2.KRX100              -0.007096         0.014997           -0.473           0.636
# L2.KORIBOR             -2.342400        12.584492           -0.186           0.852
# L2.LIBOR                3.177687         5.568818            0.571           0.568
# L2.DollarRate           4.401814         0.286898           15.343           0.000
# L2.CallRate             5.365503         4.898776            1.095           0.273
# L2.KOSPI               -0.003951         0.032707           -0.121           0.904
# ==================================================================================
#
# Results for equation KRX100
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.258204         0.922596            0.280           0.780
# L1.ExchangeRate         0.242837         0.192703            1.260           0.208
# L1.KRX100              -0.033878         0.117106           -0.289           0.772
# L1.KORIBOR           -100.446326        98.804198           -1.017           0.309
# L1.LIBOR              -56.238668        42.850727           -1.312           0.189
# L1.DollarRate          -4.767342         2.222195           -2.145           0.032
# L1.CallRate            79.650570        38.241494            2.083           0.037
# L1.KOSPI                0.059374         0.252460            0.235           0.814
# L2.ExchangeRate         0.115845         0.176486            0.656           0.512
# L2.KRX100              -0.081688         0.116663           -0.700           0.484
# L2.KORIBOR             68.842741        97.894489            0.703           0.482
# L2.LIBOR               72.491733        43.319711            1.673           0.094
# L2.DollarRate          -3.123120         2.231775           -1.399           0.162
# L2.CallRate            44.316297        38.107469            1.163           0.245
# L2.KOSPI                0.336984         0.254430            1.324           0.185
# ==================================================================================
#
# Results for equation KORIBOR
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                  -0.000528         0.000258           -2.044           0.041
# L1.ExchangeRate         0.000036         0.000054            0.663           0.507
# L1.KRX100              -0.000020         0.000033           -0.615           0.539
# L1.KORIBOR              0.278302         0.027661           10.061           0.000
# L1.LIBOR                0.024003         0.011996            2.001           0.045
# L1.DollarRate           0.000680         0.000622            1.093           0.274
# L1.CallRate             0.001241         0.010706            0.116           0.908
# L1.KOSPI                0.000081         0.000071            1.141           0.254
# L2.ExchangeRate        -0.000011         0.000049           -0.218           0.827
# L2.KRX100              -0.000037         0.000033           -1.144           0.253
# L2.KORIBOR              0.175475         0.027406            6.403           0.000
# L2.LIBOR                0.006043         0.012128            0.498           0.618
# L2.DollarRate          -0.000834         0.000625           -1.334           0.182
# L2.CallRate            -0.005845         0.010668           -0.548           0.584
# L2.KOSPI                0.000087         0.000071            1.216           0.224
# ==================================================================================
#
# Results for equation LIBOR
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.001226         0.000577            2.124           0.034
# L1.ExchangeRate         0.000008         0.000121            0.067           0.947
# L1.KRX100              -0.000023         0.000073           -0.309           0.757
# L1.KORIBOR             -0.049005         0.061809           -0.793           0.428
# L1.LIBOR                0.018895         0.026806            0.705           0.481
# L1.DollarRate          -0.000443         0.001390           -0.319           0.750
# L1.CallRate             0.006363         0.023923            0.266           0.790
# L1.KOSPI                0.000107         0.000158            0.675           0.500
# L2.ExchangeRate         0.000116         0.000110            1.051           0.293
# L2.KRX100               0.000034         0.000073            0.459           0.646
# L2.KORIBOR              0.050001         0.061240            0.816           0.414
# L2.LIBOR               -0.010904         0.027099           -0.402           0.687
# L2.DollarRate          -0.000460         0.001396           -0.329           0.742
# L2.CallRate            -0.010572         0.023839           -0.443           0.657
# L2.KOSPI               -0.000041         0.000159           -0.259           0.795
# ==================================================================================
#
# Results for equation DollarRate
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.012376         0.011131            1.112           0.266
# L1.ExchangeRate        -0.001040         0.002325           -0.447           0.655
# L1.KRX100              -0.001353         0.001413           -0.957           0.338
# L1.KORIBOR             -0.880233         1.192099           -0.738           0.460
# L1.LIBOR                0.965217         0.517006            1.867           0.062
# L1.DollarRate          -0.046201         0.026811           -1.723           0.085
# L1.CallRate            -0.106152         0.461394           -0.230           0.818
# L1.KOSPI                0.002320         0.003046            0.762           0.446
# L2.ExchangeRate        -0.000070         0.002129           -0.033           0.974
# L2.KRX100              -0.000251         0.001408           -0.178           0.859
# L2.KORIBOR              1.368871         1.181123            1.159           0.246
# L2.LIBOR               -0.354444         0.522664           -0.678           0.498
# L2.DollarRate           0.050963         0.026927            1.893           0.058
# L2.CallRate             0.058887         0.459777            0.128           0.898
# L2.KOSPI                0.000350         0.003070            0.114           0.909
# ==================================================================================
#
# Results for equation CallRate
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                  -0.000612         0.000668           -0.915           0.360
# L1.ExchangeRate         0.000152         0.000140            1.085           0.278
# L1.KRX100              -0.000007         0.000085           -0.080           0.936
# L1.KORIBOR              0.067370         0.071580            0.941           0.347
# L1.LIBOR                0.034478         0.031044            1.111           0.267
# L1.DollarRate          -0.000869         0.001610           -0.540           0.589
# L1.CallRate            -0.115691         0.027705           -4.176           0.000
# L1.KOSPI                0.000041         0.000183            0.227           0.821
# L2.ExchangeRate        -0.000061         0.000128           -0.478           0.633
# L2.KRX100               0.000074         0.000085            0.873           0.383
# L2.KORIBOR              0.167887         0.070921            2.367           0.018
# L2.LIBOR               -0.037401         0.031384           -1.192           0.233
# L2.DollarRate          -0.002423         0.001617           -1.498           0.134
# L2.CallRate            -0.126199         0.027608           -4.571           0.000
# L2.KOSPI               -0.000156         0.000184           -0.844           0.399
# ==================================================================================
#
# Results for equation KOSPI
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.109922         0.427288            0.257           0.797
# L1.ExchangeRate         0.128003         0.089248            1.434           0.152
# L1.KRX100              -0.033726         0.054236           -0.622           0.534
# L1.KORIBOR            -56.173328        45.759799           -1.228           0.220
# L1.LIBOR              -21.168294        19.845722           -1.067           0.286
# L1.DollarRate          -2.074779         1.029179           -2.016           0.044
# L1.CallRate            38.498969        17.711019            2.174           0.030
# L1.KOSPI                0.087343         0.116923            0.747           0.455
# L2.ExchangeRate         0.052201         0.081737            0.639           0.523
# L2.KRX100              -0.030484         0.054031           -0.564           0.573
# L2.KORIBOR             28.083153        45.338479            0.619           0.536
# L2.LIBOR               36.632942        20.062925            1.826           0.068
# L2.DollarRate          -1.408393         1.033616           -1.363           0.173
# L2.CallRate            23.849390        17.648948            1.351           0.177
# L2.KOSPI                0.144904         0.117836            1.230           0.219
# ==================================================================================
#
# Correlation matrix of residuals
#                 ExchangeRate    KRX100   KORIBOR     LIBOR  DollarRate  CallRate     KOSPI
# ExchangeRate        1.000000 -0.031766 -0.006731 -0.003042    0.005332  0.028558 -0.031384
# KRX100             -0.031766  1.000000  0.059090 -0.018757    0.004809 -0.035359  0.973300
# KORIBOR            -0.006731  0.059090  1.000000  0.000617    0.039903  0.279653  0.044762
# LIBOR              -0.003042 -0.018757  0.000617  1.000000    0.026498  0.019221 -0.019885
# DollarRate          0.005332  0.004809  0.039903  0.026498    1.000000  0.002798  0.012558
# CallRate            0.028558 -0.035359  0.279653  0.019221    0.002798  1.000000 -0.034230
# KOSPI              -0.031384  0.973300  0.044762 -0.019885    0.012558 -0.034230  1.000000

# %% [markdown]
# ### 예측

# %%
lagged_values = train.values[-2:]
forecast = pd.DataFrame(results.forecast(y = lagged_values, steps =352),
                       index = test.index, columns = test.columns)
forecast
# Out:
#             ExchangeRate    KRX100   KORIBOR     LIBOR  DollarRate  CallRate  \
# Date
# 2019.09.24      0.695685 -5.960292  0.000747  0.001905    0.020917  0.000127
# 2019.09.25      0.864556 -1.722748  0.001064  0.001375    0.037242  0.002276
# 2019.09.26      0.322440 -0.117962 -0.000126  0.001165    0.011768 -0.000669
# 2019.09.27      0.227121  0.254555 -0.000396  0.001320    0.015831 -0.000750
# 2019.09.30      0.083125  0.173524 -0.000610  0.001287    0.013010 -0.000507
# ...                  ...       ...       ...       ...         ...       ...
# 2021.02.17      0.098912  0.174363 -0.000880  0.001247    0.012666 -0.000688
# 2021.02.18      0.098912  0.174363 -0.000880  0.001247    0.012666 -0.000688
# 2021.02.19      0.098912  0.174363 -0.000880  0.001247    0.012666 -0.000688
# 2021.02.22      0.098912  0.174363 -0.000880  0.001247    0.012666 -0.000688
# 2021.02.23      0.098912  0.174363 -0.000880  0.001247    0.012666 -0.000688
#
#                KOSPI
# Date
# 2019.09.24 -3.280113
# 2019.09.25 -0.942406
# 2019.09.26 -0.075105
# 2019.09.27  0.124019
# 2019.09.30  0.089997
# ...              ...
# 2021.02.17  0.095799
# 2021.02.18  0.095799
# 2021.02.19  0.095799
# 2021.02.22  0.095799
# 2021.02.23  0.095799
#
# [352 rows x 7 columns]

# %%
# 차분 더한 값
forecast['real_ExchangeRate'] = df_date["ExchangeRate"].iloc[-352-1]+ forecast['ExchangeRate'].cumsum()
forecast['real_KRX100'] = df_date["KRX100"].iloc[-352-1]+ forecast['KRX100'].cumsum()
forecast['real_KORIBOR'] = df_date["KORIBOR"].iloc[-352-1]+ forecast['KORIBOR'].cumsum()
forecast['real_LIBOR'] = df_date["LIBOR"].iloc[-352-1]+ forecast['LIBOR'].cumsum()
forecast['real_DollarRate'] = df_date["DollarRate"].iloc[-352-1]+ forecast['DollarRate'].cumsum()
forecast['real_CallRate'] = df_date["CallRate"].iloc[-352-1]+ forecast['CallRate'].cumsum()
forecast['real_KOSPI'] = df_date["KOSPI"].iloc[-352-1]+ forecast['KOSPI'].cumsum()
forecast.head()
# Out:
#             ExchangeRate    KRX100   KORIBOR     LIBOR  DollarRate  CallRate  \
# Date
# 2019.09.24      0.695685 -5.960292  0.000747  0.001905    0.020917  0.000127
# 2019.09.25      0.864556 -1.722748  0.001064  0.001375    0.037242  0.002276
# 2019.09.26      0.322440 -0.117962 -0.000126  0.001165    0.011768 -0.000669
# 2019.09.27      0.227121  0.254555 -0.000396  0.001320    0.015831 -0.000750
# 2019.09.30      0.083125  0.173524 -0.000610  0.001287    0.013010 -0.000507
#
#                KOSPI  real_ExchangeRate  real_KRX100  real_KORIBOR  \
# Date
# 2019.09.24 -3.280113        1191.795685  4466.459708      1.520747
# 2019.09.25 -0.942406        1192.660240  4464.736960      1.521810
# 2019.09.26 -0.075105        1192.982680  4464.618998      1.521685
# 2019.09.27  0.124019        1193.209801  4464.873553      1.521289
# 2019.09.30  0.089997        1193.292926  4465.047076      1.520678
#
#             real_LIBOR  real_DollarRate  real_CallRate   real_KOSPI
# Date
# 2019.09.24    1.849405        98.620917       1.510127  2088.419887
# 2019.09.25    1.850780        98.658159       1.512403  2087.477481
# 2019.09.26    1.851945        98.669927       1.511734  2087.402376
# 2019.09.27    1.853265        98.685758       1.510984  2087.526396
# 2019.09.30    1.854552        98.698768       1.510477  2087.616393

# %%
#환율 그래프 보자
test = df_date.iloc[-352:, :1]
test["real_ExchangeRate"] = forecast["real_ExchangeRate"]
test.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Out:
# Date
# 2019.09.24                                                      1193.1
# 2019.09.25                                                      1194.0
# 2019.09.26                                                      1198.3
# 2019.09.27                                                      1199.1
# 2019.09.30                                                      1201.3
#                                            ...
# 2021.02.18                                                      1107.7
# 2021.02.19                                                      1105.7
# 2021.02.22                                                      1107.1
# 2021.02.23                                                      1106.5
# real_ExchangeRate    Date
# 2019.09.24    1191.795685
# 2019.09.25    1...
# Name: ExchangeRate, Length: 353, dtype: object
